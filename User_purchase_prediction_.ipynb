# %% [markdown]
# <a href="https://colab.research.google.com/github/RiH-137/User-purchase-prediction-/blob/main/User_purchase_prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Prediction system to predict which user is going to buy a product displayed on a social media advertisement

# %% [markdown]
# Classification

# %% [markdown]
# dataset:- https://raw.githubusercontent.com/sharmaroshan/Social-Networks-Ads/master/Social_Network_Ads.csv

# %% [markdown]
# #### (batch/vanilla Gradient boosting vs stochastic gd)

# %% [markdown]
#    ....

# %%
import pandas as pd
import numpy as np
import time

# %%
df=pd.read_csv('https://raw.githubusercontent.com/sharmaroshan/Social-Networks-Ads/master/Social_Network_Ads.csv')
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
df.head()
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510    Male  19.0          19000.0          0
# 1  15810944    Male  35.0          20000.0          0
# 2  15668575  Female  26.0          43000.0          0
# 3  15603246  Female  27.0          57000.0          0
# 4  15804002    Male  19.0          76000.0          0

# %% [markdown]
# We need EstimatedSalary Purchased abd Age

# %%
df = df.drop(columns=["User ID", "Gender"])

# %%
df.head()
# Out:
#     Age  EstimatedSalary  Purchased
# 0  19.0          19000.0          0
# 1  35.0          20000.0          0
# 2  26.0          43000.0          0
# 3  27.0          57000.0          0
# 4  19.0          76000.0          0

# %% [markdown]
# In pandas DataFrames, iloc stands for integer-location based indexing. It's a method used to select specific rows and columns by their numerical positions within the DataFrame, regardless of any custom labels or names assigned to those rows or columns.

# %% [markdown]
# X=df.iloc[:,0:2]
#
# Selects columns:
# : in the first position ([:,...]) indicates selecting all rows (from the beginning : to the end :).
# 0:2 specifies the column range to include: from the 0th index (column A) up to, but not including, the 2nd index (column B). So, it selects columns A and B.
# Assigns the result (a DataFrame containing columns A and B) to the variable X.
#
#
#
# y=df.iloc[:,-1]
#
# Selects a single column:
# : in the second position ([...,:]) indicates selecting all columns (from the beginning : to the end :).
# -1 refers to the last column (C in this example) using zero-based indexing.
# Assigns the result (a pandas Series containing the values from column C) to the variable y.
# In simpler terms:
#
# X becomes a new DataFrame containing only the first two columns (A and B) from the original df.
# y becomes a Series containing the values from the last column (C) of df.

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X
# Out:
#       Age  EstimatedSalary
# 0    19.0          19000.0
# 1    35.0          20000.0
# 2    26.0          43000.0
# 3    27.0          57000.0
# 4    19.0          76000.0
# ..    ...              ...
# 395  46.0          41000.0
# 396  51.0          23000.0
# 397  50.0          20000.0
# 398  36.0          33000.0
# 399  49.0          36000.0
#
# [400 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)
X_scaled.shape
# Out:
# (400, 2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2, random_state=2)

# %%
X_train
# Out:
#       Age  EstimatedSalary
# 205  47.0          47000.0
# 354  36.0          99000.0
# 3    27.0          57000.0
# 264  48.0          90000.0
# 194  28.0          89000.0
# ..    ...              ...
# 299  46.0         117000.0
# 22   48.0          41000.0
# 72   20.0          23000.0
# 15   29.0          80000.0
# 168  29.0         148000.0
#
# [320 rows x 2 columns]

# %%
X_test
# Out:
#       Age  EstimatedSalary
# 94   29.0          83000.0
# 32   21.0          16000.0
# 225  37.0          53000.0
# 157  29.0          75000.0
# 356  54.0          70000.0
# ..    ...              ...
# 188  35.0          72000.0
# 223  60.0         102000.0
# 65   24.0          58000.0
# 262  55.0         125000.0
# 186  20.0          82000.0
#
# [80 rows x 2 columns]

# %%
#y is our target value
y_train
# Out:
# 205    0
# 354    1
# 3      0
# 264    1
# 194    0
#       ..
# 299    1
# 22     1
# 72     0
# 15     0
# 168    1
# Name: Purchased, Length: 320, dtype: int64

# %%
y_test
# Out:
# 94     0
# 32     0
# 225    0
# 157    0
# 356    1
#       ..
# 188    0
# 223    1
# 65     0
# 262    1
# 186    0
# Name: Purchased, Length: 80, dtype: int64

# %%
X_train.shape
# Out:
# (320, 2)

# %%
X_test.shape
# Out:
# (80, 2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model= Sequential()

model.add(Dense(10,activation='relu',input_dim=2))                #input_dim means input dimension
model.add(Dense(10,activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 10)                30
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 1)                 11
#
# ...
# Total params: 151 (604.00 Byte)
# Trainable params: 151 (604.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print("X_scaled shape:", X_scaled.shape)
print("y shape:", y.shape)
# Out:
# X_scaled shape: (400, 2)
# y shape: (400,)

# %%
print("Model output shape:", model.output_shape)
# Out:
# Model output shape: (None, 1)

# %%
#compiling the model

model.compile(loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# batch size=1, it means fir the training we give 1 row for the trainig (number to datapoint go for training at 1 time.) and if the batch_size=320 means we are given 320 rows for the process.

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=1)  #vanila Gradient decent
# Out:
# Epoch 1/50
# 320/320 [==============================] - 1s 2ms/step - loss: 0.6461 - accuracy: 0.6531
# Epoch 2/50
# 320/320 [==============================] - 0s 1ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 3/50
# 320/320 [==============================] - 0s 1ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 4/50
# 320/320 [==============================] - 0s 1ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 5/50
# 320/320 [==============================] - 0s 1ms/step - loss: 0.6462 - accuracy: 0.6531
# Epoch 6/50
# 320/320 [==============================] - 0s 1ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 7/50
# 320/320 [==============================] - 0s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 8/50
# 320/320 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 9/50
# 320/320 [==============================] - 1s 2ms/step - loss: 0.6463 - accuracy: 0.6531
# Epoch 10/50
# ...

# %%
320/32
# Out:
# 10.0

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=32)  #mini-batch Gradient decent
# Out:
# Epoch 1/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6456 - accuracy: 0.6531
# Epoch 2/10
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6456 - accuracy: 0.6531
# Epoch 3/10
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6456 - accuracy: 0.6531
# Epoch 4/10
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6455 - accuracy: 0.6531
# Epoch 5/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6456 - accuracy: 0.6531
# Epoch 6/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6456 - accuracy: 0.6531
# Epoch 7/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6456 - accuracy: 0.6531
# Epoch 8/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6455 - accuracy: 0.6531
# Epoch 9/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6456 - accuracy: 0.6531
# Epoch 10/10
# ...
